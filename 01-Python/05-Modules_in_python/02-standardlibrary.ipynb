# %% [markdown]
# Python's Standard Library is a vast collection of modules and packages that come bundled with Python, providing a wide range of functionalities out of the box.

# %%
import array
arr=array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
## random
import random
print(random.randint(1,10))
print(random.choice(['apple','banana','cherry','guava']))
# Out:
# 5
# banana

# %%
## file and directory access
import os

##get current directory
print(os.getcwd())
# Out:
# c:\Users\HP\Desktop\machine learning\01-python\05-Modules_in_python

# %%
## make directory
os.mkdir('test_dir')

# %%
## High level operations on file and collecton of files
import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
## Data serialiation
import json
data={'name':'omkar','age':21}

json_str=json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "omkar", "age": 21}
# <class 'str'>
# {'name': 'omkar', 'age': 21}
# <class 'dict'>

# %%
## csv
import csv

with open('example.csv',mode='w',newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['omkar',21])

with open('example.csv',mode='r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['omkar', '21']

# %%
## datetime
from datetime import datetime,timedelta
now=datetime.now()
print(now)

yesterday=now-timedelta(days=1)
print(yesterday)
# Out:
# 2026-08-04 17:35:26.973200
# 2026-08-03 17:35:26.973200

# %%
## time
import time
print(time.time())

time.sleep(2)
print(time.time())
# Out:
# 1785845178.3075383
# 1785845180.3083003

# %%
## Regular expression
import re

pattern=r'\d+' ## digits
text='There are 123 apples'
match=re.search(pattern,text)
print(match.group())
# Out:
# 123
