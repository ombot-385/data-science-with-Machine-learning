# %%
##Integer types
age=35
type(age)
# Out:
# int

# %%
##floating point datatypes
height=5.11
print(height)
print(type(height))
# Out:
# 5.11
# <class 'float'>

# %%
##string
name="omkar"
print(name)
print(type(name))
# Out:
# omkar
# <class 'str'>

# %%
##boolean
True
print(type(True))
# Out:
# <class 'bool'>

# %%
is_true=True
print(is_true)
print(type(is_true))
# Out:
# True
# <class 'bool'>

# %%
a=10
b=10
print(a==b)
type(a==b)
# Out:
# True
# bool

# %%
#common errors
#result="hello"+5--> this will produce error can only concatenate str(not "int") to str
result="hello"+str(5)
print(result)
# Out:
# hello5
