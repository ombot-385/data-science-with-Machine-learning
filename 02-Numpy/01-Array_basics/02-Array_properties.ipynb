# %% [markdown]
# 1. ndim – the number of dimensions (axes) in the array
# 2. shape – the size of the array for each dimension
# 3. size – the total number of elements in the array
# 4. dtype – the data type of the elements in the array

# %%
import numpy as np
sales=[0,5,10,15,20,25]
sales_array=np.array(sales)
type(sales_array)
# Out:
# numpy.ndarray

# %%
print(f"ndim:{sales_array.ndim}")
print(f"shape:{sales_array.shape}")
print(f"size:{sales_array.size}")
print(f"dtype:{sales_array.dtype}")
# Out:
# ndim:1
# shape:(6,)
# size:6
# dtype:int64

# %%
sales2=[[0,5,10,15,20,25],[30,35,40,45,50,55]]
sales2_array=np.array(sales2)

# %%
print(f"ndim:{sales2_array.ndim}")
print(f"shape:{sales2_array.shape}")
print(f"size:{sales2_array.size}")
print(f"dtype:{sales2_array.dtype}")
# Out:
# ndim:2
# shape:(2, 6)
# size:12
# dtype:int64
