# %%
import numpy as np
product_array=np.array(['fruits','vegetable','cereal','dairy','eggs','snacks','beverages','coffee','tea','spices'])

# %%
product_array2D=product_array.reshape(2,5)
product_array2D
# Out:
# array([['fruits', 'vegetable', 'cereal', 'dairy', 'eggs'],
#        ['snacks', 'beverages', 'coffee', 'tea', 'spices']], dtype='<U9')

# %%
product_array2D[1,2]
# Out:
# np.str_('coffee')

# %%
product_array2D[:,2:]
# Out:
# array([['cereal', 'dairy', 'eggs'],
#        ['coffee', 'tea', 'spices']], dtype='<U9')

# %%
product_array2D[1:,:]
# Out:
# array([['snacks', 'beverages', 'coffee', 'tea', 'spices']], dtype='<U9')
