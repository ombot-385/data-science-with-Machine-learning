# %%
import numpy as np
product_array=np.array(['fruits','vegetable','cereal','dairy','eggs','snacks','beverages','coffee','tea','spices'])
product_array
# Out:
# array(['fruits', 'vegetable', 'cereal', 'dairy', 'eggs', 'snacks',
#        'beverages', 'coffee', 'tea', 'spices'], dtype='<U9')

# %%
print (product_array[1])
print(product_array[-1])
# Out:
# vegetable
# spices

# %%
product_array[:5]
# Out:
# array(['fruits', 'vegetable', 'cereal', 'dairy', 'eggs'], dtype='<U9')

# %%
product_array[2:5]
# Out:
# array(['cereal', 'dairy', 'eggs'], dtype='<U9')

# %%
product_array[5::2]
# Out:
# array(['snacks', 'coffee', 'spices'], dtype='<U9')
